# %% [markdown]
#  Day 01 - Numpy Introduction and all details

# %% [markdown]
# 1. Setup & Install

# %%
#pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\Users\Dell\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %% [markdown]
# 2. What is NumPy?
#
# NumPy (Numerical Python) is a library for numerical computing using fast multidimensional arrays.

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])
print(arr)
# Out:
# [1 2 3 4 5]

# %% [markdown]
# 3. Why Use NumPy?
#
# Faster than Python lists and uses less memory.

# %%
import numpy as np

list1 = [1, 2, 3, 4]
array1 = np.array([1, 2, 3, 4])

print(array1 * 2)
# Out:
# [2 4 6 8]

# %% [markdown]
# 4. Creating NumPy Arrays
