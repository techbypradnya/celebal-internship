# %% [markdown]
#  Day 01 - Numpy Introduction and all details

# %% [markdown]
# 1. Setup & Install

# %%
#pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %% [markdown]
# 2. What is NumPy?
#
# NumPy (Numerical Python) is a library for numerical computing using fast multidimensional arrays.
